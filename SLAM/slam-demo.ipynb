# %%
import matplotlib.pyplot as plt
from TUM_dataset import TUMVisualInertialDataset

# %%
# Load TUM data (one sequence only)
dataset = TUMVisualInertialDataset(path='/home/ilari/Downloads/dataset-corridor4_512_16/dso', sequence_length=5, skip_frames=5)
print(len(dataset))
X = dataset[0]
print(X['cam0'].shape, X['dt'].shape, X['acc'].shape, X['gyro'].shape, X['gt_pose'].shape)
plt.imshow(X['cam0'][0].numpy());
# Out:
# 382
# torch.Size([5, 505, 502, 3]) torch.Size([219]) torch.Size([219, 3]) torch.Size([219, 3]) torch.Size([5, 7])
